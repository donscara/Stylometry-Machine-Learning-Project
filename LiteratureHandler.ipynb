# %% [markdown]
# # D7059E
#
# *   Jacob Yousif
# *   Donato Scarano

# %% [markdown]
# ## Importing libraries

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %%capture
# !pip install chardet

# %%
# %%capture

import os
import re
import chardet
import pandas as pd

from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## Pre-processing

# %%
df = pd.DataFrame()

# %%
books_meta = {
    "ARoomWithAView.txt": {
        "publish_year": 1908,
        "author": "E. M. Forster",
        "genre": "Romance",
        "last_name": "Forster",
        "avg_rating": 3.90,
        "code": 0,
    },
    "Dracula.txt": {
        "publish_year": 1897,
        "author": "Bram Stoker",
        "genre": "Gothic Horror",
        "last_name": "Stoker",
        "avg_rating": 4.01,
        "code": 1,
    },
    "Frankenstein.txt": {
        "publish_year": 1818,
        "author": "Mary Shelley",
        "genre": "Gothic Horror",
        "last_name": "Shelley",
        "avg_rating": 3.87,
        "code": 2,
    },
    "HeartOfDarkness.txt": {
        "publish_year": 1899,
        "author": "Joseph Conrad",
        "genre": "Psychological Fiction",
        "last_name": "Conrad",
        "avg_rating": 3.43,
        "code": 3,
    },
    "LesMiserables.txt": {
        "publish_year": 1862,
        "author": "Victor Hugo",
        "genre": "Historical Fiction",
        "last_name": "Hugo",
        "avg_rating": 4.20,
        "code": 4,
    },
    "MadameBovary.txt": {
        "publish_year": 1857,
        "author": "Gustave Flaubert",
        "genre": "Literary Realism",
        "last_name": "Flaubert",
        "avg_rating": 3.70,
        "code": 5,
    },
    "Middlemarch.txt": {
        "publish_year": 1871,
        "author": "George Eliot",
        "genre": "Victorian Novel",
        "last_name": "Eliot",
        "avg_rating": 4.02,
        "code": 6,
    },
    "Moby-Dick.txt": {
        "publish_year": 1851,
        "author": "Herman Melville",
        "genre": "Adventure Fiction",
        "last_name": "Melville",
        "avg_rating": 3.54,
        "code": 7,
    },
    "OliverTwist.txt": {
        "publish_year": 1838,
        "author": "Charles Dickens",
        "genre": "Social Novel",
        "last_name": "Dickens",
        "avg_rating": 3.88,
        "code": 8,
    },
    "PrideAndPrejudice.txt": {
        "publish_year": 1813,
        "author": "Jane Austen",
        "genre": "Romance",
        "last_name": "Austen",
        "avg_rating": 4.29,
        "code": 9,
    },
    "TheAdventuresOfHuckleberryFinn.txt": {
        "publish_year": 1884,
        "author": "Mark Twain",
        "genre": "Picaresque Novel",
        "last_name": "Twain",
        "avg_rating": 3.83,
        "code": 10,
    },
    "TheCallOfTheWild.txt": {
        "publish_year": 1903,
        "author": "Jack London",
        "genre": "Adventure Fiction",
        "last_name": "London",
        "avg_rating": 3.90,
        "code": 11,
    },
    "ThePictureOfDorianGray.txt": {
        "publish_year": 1890,
        "author": "Oscar Wilde",
        "genre": "Philosophical Fiction",
        "last_name": "Wilde",
        "avg_rating": 4.12,
        "code": 12,
    },
    "TheWindInTheWillows.txt": {
        "publish_year": 1908,
        "author": "Kenneth Grahame",
        "genre": "Children's Fiction",
        "last_name": "Grahame",
        "avg_rating": 4.01,
        "code": 13,
    },
    "TheWonderfulWizardOfOz.txt": {
        "publish_year": 1900,
        "author": "L. Frank Baum",
        "genre": "Fantasy",
        "last_name": "Baum",
        "avg_rating": 4.00,
        "code": 14,
    },
    "WarAndPeace.txt": {
        "publish_year": 1869,
        "author": "Leo Tolstoy",
        "genre": "Historical Fiction",
        "last_name": "Tolstoy",
        "avg_rating": 4.16,
        "code": 15,
    },
    "TheJewelOfSevenStars.txt": {
        "publish_year": 1903,
        "author": "Bram Stoker",
        "genre": "Horror",
        "last_name": "Stoker",
        "avg_rating": 3.42,
        "code": 1,
    },
    "TheLairOfTheWhiteWorm.txt": {
        "publish_year": 1911,
        "author": "Bram Stoker",
        "genre": "Horror",
        "last_name": "Stoker",
        "avg_rating": 2.78,
        "code": 1,
    },
    "ATaleOfTwoCities.txt": {
        "publish_year": 1859,
        "author": "Charles Dickens",
        "genre": "Historical Fiction",
        "last_name": "Dickens",
        "avg_rating": 3.87,
        "code": 8,
    },
    "GreatExpectations.txt": {
        "publish_year": 1861,
        "author": "Charles Dickens",
        "genre": "Bildungsroman",
        "last_name": "Dickens",
        "avg_rating": 3.79,
        "code": 8,
    },
    "APassageToIndia.txt": {
        "publish_year": 1924,
        "author": "E. M. Forster",
        "genre": "Historical Fiction",
        "last_name": "Forster",
        "avg_rating": 3.68,
        "code": 0,
    },
    "HowardsEnd.txt": {
        "publish_year": 1910,
        "author": "E. M. Forster",
        "genre": "Domestic Fiction",
        "last_name": "Forster",
        "avg_rating": 3.96,
        "code": 0,
    },
    "SilasMarner.txt": {
        "publish_year": 1861,
        "author": "George Eliot",
        "genre": "Realist Novel",
        "last_name": "Eliot",
        "avg_rating": 3.68,
        "code": 6,
    },
    "TheMillOnTheFloss.txt": {
        "publish_year": 1860,
        "author": "George Eliot",
        "genre": "Realist Novel",
        "last_name": "Eliot",
        "avg_rating": 3.82,
        "code": 6,
    },
    "SentimentalEducation.txt": {
        "publish_year": 1869,
        "author": "Gustave Flaubert",
        "genre": "Bildungsroman",
        "last_name": "Flaubert",
        "avg_rating": 3.81,
        "code": 5,
    },
    "Salammbo.txt": {
        "publish_year": 1862,
        "author": "Gustave Flaubert",
        "genre": "Historical Fiction",
        "last_name": "Flaubert",
        "avg_rating": 3.74,
        "code": 5,
    },
    "Bartleby.txt": {
        "publish_year": 1853,
        "author": "Herman Melville",
        "genre": "Fiction",
        "last_name": "Melville",
        "avg_rating": 3.93,
        "code": 7,
    },
    "ThePiazzaTales.txt": {
        "publish_year": 1856,
        "author": "Herman Melville",
        "genre": "Psychological Fiction",
        "last_name": "Melville",
        "avg_rating": 3.84,
        "code": 7,
    },
    "WhiteFang.txt": {
        "publish_year": 1906,
        "author": "Jack London",
        "genre": "Adventure Fiction",
        "last_name": "London",
        "avg_rating": 4.02,
        "code": 11,
    },
    "TheSeaWolf.txt": {
        "publish_year": 1904,
        "author": "Jack London",
        "genre": "Psychological Fiction",
        "last_name": "London",
        "avg_rating": 4.05,
        "code": 11,
    },
    "SenseAndSensibility.txt": {
        "publish_year": 1811,
        "author": "Jane Austen",
        "genre": "Romance",
        "last_name": "Austen",
        "avg_rating": 4.08,
        "code": 9,
    },
    "Emma.txt": {
        "publish_year": 1815,
        "author": "Jane Austen",
        "genre": "Comedy",
        "last_name": "Austen",
        "avg_rating": 4.05,
        "code": 9,
    },
    "LordJim.txt": {
        "publish_year": 1900,
        "author": "Joseph Conrad",
        "genre": "Adventure Fiction",
        "last_name": "Conrad",
        "avg_rating": 3.62,
        "code": 3,
    },
    "Nostromo.txt": {
        "publish_year": 1904,
        "author": "Joseph Conrad",
        "genre": "Political Fiction",
        "last_name": "Conrad",
        "avg_rating": 3.81,
        "code": 3,
    },
    "TheGoldenAge.txt": {
        "publish_year": 1895,
        "author": "Kenneth Grahame",
        "genre": "Children's Literature",
        "last_name": "Grahame",
        "avg_rating": 3.80,
        "code": 13,
    },
    "DreamDays.txt": {
        "publish_year": 1898,
        "author": "Kenneth Grahame",
        "genre": "Collection of Stories",
        "last_name": "Grahame",
        "avg_rating": 3.81,
        "code": 13,
    },
    "TheMarvelousLandOfOz.txt": {
        "publish_year": 1904,
        "author": "L. Frank Baum",
        "genre": "Children's Literature",
        "last_name": "Baum",
        "avg_rating": 3.80,
        "code": 14,
    },
    "OzmaOfOz.txt": {
        "publish_year": 1907,
        "author": "L. Frank Baum",
        "genre": "Children's Literature",
        "last_name": "Baum",
        "avg_rating": 3.96,
        "code": 14,
    },
    "AnnaKarenina.txt": {
        "publish_year": 1877,
        "author": "Leo Tolstoy",
        "genre": "Realist Novel",
        "last_name": "Tolstoy",
        "avg_rating": 4.09,
        "code": 15,
    },
    "WhatMenLiveBy.txt": {
        "publish_year": 1885,
        "author": "Leo Tolstoy",
        "genre": "Philosophical Fiction",
        "last_name": "Tolstoy",
        "avg_rating": 4.10,
        "code": 15,
    },
    "TheAdventuresOfTomSawyer.txt": {
        "publish_year": 1876,
        "author": "Mark Twain",
        "genre": "Bildungsroman",
        "last_name": "Twain",
        "avg_rating": 3.92,
        "code": 10,
    },
    "AConnecticutYankeeInKingArthursCourt.txt": {
        "publish_year": 1889,
        "author": "Mark Twain",
        "genre": "Satire",
        "last_name": "Twain",
        "avg_rating": 3.77,
        "code": 10,
    },
    "TheLastMan.txt": {
        "publish_year": 1826,
        "author": "Mary Shelley",
        "genre": "Apocalyptic Fiction",
        "last_name": "Shelley",
        "avg_rating": 3.37,
        "code": 2,
    },
    "Valperga.txt": {
        "publish_year": 1823,
        "author": "Mary Shelley",
        "genre": "Historical Novel",
        "last_name": "Shelley",
        "avg_rating": 3.54,
        "code": 2,
    },
    "TheImportanceOfBeingEarnest.txt": {
        "publish_year": 1895,
        "author": "Oscar Wilde",
        "genre": "Comedy",
        "last_name": "Wilde",
        "avg_rating": 4.17,
        "code": 12,
    },
    "LadyWindermeresFan.txt": {
        "publish_year": 1892,
        "author": "Oscar Wilde",
        "genre": "Comedy",
        "last_name": "Wilde",
        "avg_rating": 3.92,
        "code": 12,
    },
    "TheHistoryOfACrime.txt": {
        "publish_year": 1877,
        "author": "Victor Hugo",
        "genre": "Historical",
        "last_name": "Hugo",
        "avg_rating": 3.66,
        "code": 4,
    },
    "Ninety-Three.txt": {
        "publish_year": 1874,
        "author": "Victor Hugo",
        "genre": "Historical Novel",
        "last_name": "Hugo",
        "avg_rating": 4.08,
        "code": 4,
    },
}

# %%
directory = 'literature/'

# %%
def filename_to_title(filename):
    name_without_ext = filename.replace(".txt", "")
    title = " ".join(
        [
            word if i == 0 else word.capitalize()
            for i, word in enumerate(re.findall("[A-Z][^A-Z]*", name_without_ext))
        ]
    )
    return title

# %%
def read_text_file(file_path):
    with open(file_path, 'rb') as file:
        raw_data = file.read()
    result = chardet.detect(raw_data)
    encoding = result['encoding']
    with open(file_path, 'r', encoding=encoding) as file:
        text = file.read()
    
    return text

# %%
files = [f for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f))]

# %%
print('Books:', files)
# Out:
# Books: ['AConnecticutYankeeInKingArthursCourt.txt', 'AnnaKarenina.txt', 'APassageToIndia.txt', 'ARoomWithAView.txt', 'ATaleOfTwoCities.txt', 'Bartleby.txt', 'Dracula.txt', 'DreamDays.txt', 'Emma.txt', 'Frankenstein.txt', 'GreatExpectations.txt', 'HeartOfDarkness.txt', 'HowardsEnd.txt', 'LadyWindermeresFan.txt', 'LesMiserables.txt', 'LordJim.txt', 'MadameBovary.txt', 'Middlemarch.txt', 'Moby-Dick.txt', 'Ninety-Three.txt', 'Nostromo.txt', 'OliverTwist.txt', 'OzmaOfOz.txt', 'PrideAndPrejudice.txt', 'Salammbo.txt', 'SenseAndSensibility.txt', 'SentimentalEducation.txt', 'SilasMarner.txt', 'TheAdventuresOfHuckleberryFinn.txt', 'TheAdventuresOfTomSawyer.txt', 'TheCallOfTheWild.txt', 'TheGoldenAge.txt', 'TheHistoryOfACrime.txt', 'TheImportanceOfBeingEarnest.txt', 'TheJewelOfSevenStars.txt', 'TheLairOfTheWhiteWorm.txt', 'TheLastMan.txt', 'TheMarvelousLandOfOz.txt', 'TheMillOnTheFloss.txt', 'ThePiazzaTales.txt', 'ThePictureOfDorianGray.txt', 'TheSeaWolf.txt', 'TheWindInTheWillows.txt', 'TheWon
# ...

# %%
files.sort()

# %%
df['Book'] = [filename_to_title(book) for book in files]

# %%
df['Author'] = [books_meta[x]['author'] for x in files]

# %%
df['AuthorLastName'] = [books_meta[x]['last_name'] for x in files]

# %%
df['Genre'] = [books_meta[x]['genre'] for x in files]

# %%
df['Publish-Year'] = [books_meta[x]['publish_year'] for x in files]

# %%
df['Average-Rating'] = [books_meta[x]['avg_rating'] for x in files]

# %%
books = [read_text_file(directory + item) for item in files]

# %%
df['Text'] = books

# %%
df['Text-Length'] = df['Text'].apply(len)

# %%
label_encoder = LabelEncoder()
df['AuthorCode'] = label_encoder.fit_transform(df['AuthorLastName'])

# %%
df_sorted = df.sort_values(by='Publish-Year')
df_sorted.reset_index(drop=True, inplace=True)

# %%
def remove_whitespace(text):
    return  " ".join(text.split())

# %%
df_sorted['Text'] = df_sorted['Text'].apply(remove_whitespace)

# %%
df_sorted
# Out:
#                                           Book            Author  \
# 0                        Sense And Sensibility       Jane Austen
# 1                          Pride And Prejudice       Jane Austen
# 2                                         Emma       Jane Austen
# 3                                 Frankenstein      Mary Shelley
# 4                                     Valperga      Mary Shelley
# 5                                 The Last Man      Mary Shelley
# 6                                 Oliver Twist   Charles Dickens
# 7                                   Moby- Dick   Herman Melville
# 8                                     Bartleby   Herman Melville
# 9                             The Piazza Tales   Herman Melville
# 10                               Madame Bovary  Gustave Flaubert
# 11                        A Tale Of Two Cities   Charles Dickens
# 12                       The Mill On The Floss      George Eliot
# ...

# %%
csv_file_path = 'datasets/Literature.csv'
df_sorted.to_csv(csv_file_path, index=False)

# %%
total_text_length = df['Text-Length'].sum()

# %%
print('The total text length of the books is:', total_text_length)
# Out:
# The total text length of the books is: 33378295
